# %%
from pal_plots import *
# pal test
sensor_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_dat.csv"
gps_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_gps.csv"
se_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_fsl.csv"
tm_file = '..\..\Python\Data Files\pal_test\2024-02-26-serial-8183-flight-0004.csv'

# # dm3 files
# sensor_file = "..\..\Python\Data Files\dm3\pal_fsl_test_dat.csv"
# gps_file = "..\..\Python\Data Files\dm3\gps_dm3.csv"
# se_file = "..\..\Python\Data Files\dm3\pal_fsl_test_fsl.csv"
# tm_file = '..\..\Python\Data Files\dm3\DM3-2023-11-12-serial-8183-flight-0002.csv'
# Ask Hannah for properly formatted data files if you need them, they're too big for github
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\hkadl\AppData\Local\Temp\ipykernel_23260\3492252346.py:3: SyntaxWarning: invalid escape sequence '\.'
#   sensor_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_dat.csv"
# C:\Users\hkadl\AppData\Local\Temp\ipykernel_23260\3492252346.py:4: SyntaxWarning: invalid escape sequence '\.'
#   gps_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_gps.csv"
# C:\Users\hkadl\AppData\Local\Temp\ipykernel_23260\3492252346.py:5: SyntaxWarning: invalid escape sequence '\.'
#   se_file = "..\..\Python\Data Files\pal_test\pal_fsl_test_fsl.csv"
# ...

# %%
sd = load_sensor_data(sensor_file)
plot_accel(sd)

# %% [markdown]
# This data was already trimmed to flight time, but I can look at the accel plot and trim it more to apogee. Trimming data will also adjust the displayed starting time to 0, but the original ['time'] field of the dataset is still saved.

# %%
t_apo = 3150
sd_trimmed = trim_data(sd, 0, 3150) # trim data
## Make some more plots from trimmed data
plot_accel(sd_trimmed, name="Pal test flight until apo", include_H=False) # plot only imu accel, not high g accel
plot_pressure(sd_trimmed)
plot_pressure_alt(sd_trimmed)
plot_angular_rate(sd_trimmed)

# %% [markdown]
# ### GPS Plots

# %%
gd = load_gps_data(gps_file)
gps_trim = trim_data(gd, sd_trimmed['time'][0],sd_trimmed['time'][0]+400)
plot_gps_state(gps_trim);

# %% [markdown]
# ### State Estimation Plots

# %%
ed = load_se_data(se_file)
plot_vertical_se(ed);
